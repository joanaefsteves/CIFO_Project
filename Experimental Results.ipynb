# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the Grid Search results
results1 = pd.read_csv('fitness_per_run.csv')
results2 = pd.read_csv('avg_fitness_per_generation.csv')

# %%
results2
# Out:
#          mutation            crossover                        selection  \
# 0   swap_mutation  one_point_crossover  fitness_proportionate_selection
# 1   swap_mutation  one_point_crossover  fitness_proportionate_selection
# 2   swap_mutation  one_point_crossover  fitness_proportionate_selection
# 3   swap_mutation  one_point_crossover  fitness_proportionate_selection
# 4   swap_mutation  one_point_crossover  fitness_proportionate_selection
# ..            ...                  ...                              ...
# 95  swap_mutation  one_point_crossover  fitness_proportionate_selection
# 96  swap_mutation  one_point_crossover  fitness_proportionate_selection
# 97  swap_mutation  one_point_crossover  fitness_proportionate_selection
# 98  swap_mutation  one_point_crossover  fitness_proportionate_selection
# 99  swap_mutation  one_point_crossover  fitness_proportionate_selection
#
#     elitism  generation   avg_fitness   elitism_flag  \
# ...

# %%
results2["elitism_flag"] = np.where(
    results2["elitism"] != 0, "elitism_true", "elitism_false"
)

# %%
results2["combination"] = (
    results2["mutation"] + " + " +
    results2["crossover"] + " + " +
    results2["selection"] + " + " +
    results2["elitism_flag"]
)

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=results2, x="generation", y="avg_fitness", hue="combination", marker="o")
plt.title("Evolution of Average Fitness per Generation")
plt.xlabel("Generation")
plt.ylabel("Average Fitness")
plt.grid(True)
plt.tight_layout()
plt.show()
